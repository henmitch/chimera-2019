# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

# %%
import matplotlib.animation as anim

# %%
# %%time
G = nx.read_gexf("0.058-0.010.gexf", version="1.2draft")
# Out:
# CPU times: user 4.35 s, sys: 996 ms, total: 5.35 s
# Wall time: 6.87 s

# %%
pos = {i: [G.nodes[i]["viz"]["position"]["x"], G.nodes[i]["viz"]["position"]["y"]] for i in G.nodes}

# %%
node_size = np.array([G.nodes[i]["viz"]["size"] for i in G.nodes])

# %%
keys = [G.nodes[i].keys() for i in G.nodes]

# %%
len(G.nodes["0"]["potential"])
# Out:
# 2500

# %%
# %%time
ims = []
for t in range(len(G.nodes["0"]["potential"][:4])):
    potentials = np.array([G.nodes[i]["potential"][t][0] for i in G.nodes])
    nx.draw_networkx(G, pos=pos, node_size=1.5*node_size, arrowsize=1, width=0.05,
                     edge_color="#777777", node_color=potentials, with_labels=False,
                     vmin=-1, vmax=1, animated=True)
    ims.append([plt.gca()])
# Out:
# CPU times: user 12.2 s, sys: 269 ms, total: 12.4 s
# Wall time: 12.3 s

# %%
ani = anim.ArtistAnimation(plt.gcf(), ims, interval=50, blit=True,
                           repeat_delay=1000)

# %%
ani.save("test.gif")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-aca074c02a16> in <module>
# ----> 1 ani.save("test.gif")
#
# /usr/local/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1198                         # TODO: See if turning off blit is really necessary
#    1199                         anim._draw_next_frame(d, blit=False)
# -> 1200                     writer.grab_frame(**savefig_kwargs)
#    1201
#    1202         # Reconnect signal for first draw if necessary
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
# ...

# %%
ani
